# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
male = data[data['sex'] == 'Male']
female = data[data['sex'] == 'Female']
maleCount = len(male)
femaleCount = len(female)

print(maleCount, femaleCount)
# Out:
# 21790 10771

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
male = data[data['sex'] == 'Male']
maleAvg = male['age'].mean()

print(maleAvg)
# Out:
# 39.43354749885268

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
americans = data[data['native-country'] == 'United-States']
americansCount = len(americans)
peopleCount = len(data)
percentAmericans = americansCount / peopleCount * 100

print(percentAmericans)
# Out:
# 89.5857006848684

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
moreSalary = data[data['salary'] == '>50K']
lessSalary = data[data['salary'] == '<=50K']
avgMoreSalary = moreSalary['age'].mean()
avgLessSalary = lessSalary['age'].mean()
stdMoreSalary = moreSalary['age'].std()
stdLessSalary = lessSalary['age'].std()

print(avgLessSalary, avgMoreSalary, stdLessSalary, stdMoreSalary)
# Out:
# 36.78373786407767 44.24984058155847 14.02008849082488 10.519027719851826

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
import pandas as pd

low_education = [
    'Preschool', '1st-4th', '5th-6th', '7th-8th',
    '9th', '10th', '11th', '12th', 'HS-grad'
]

data = pd.read_csv("./data/adult.data.csv")
moreSalary = data[data['salary'] == '>50K']
lowGradMoreSalary = moreSalary[moreSalary['education'].isin(low_education)]
if len(lowGradMoreSalary) > 0:
    print("False, ", len(moreSalary), len(lowGradMoreSalary))
else:
    print("True")
# Out:
# False,  7841 1919

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
grouped_data = data.groupby(['race', 'sex'])
avgAgeGrouped = grouped_data['age'].mean()

print(avgAgeGrouped)
# Out:
# race                sex
# Amer-Indian-Eskimo  Female    37.117647
#                     Male      37.208333
# Asian-Pac-Islander  Female    35.089595
#                     Male      39.073593
# Black               Female    37.854019
#                     Male      37.682600
# Other               Female    31.678899
#                     Male      34.654321
# White               Female    36.811618
#                     Male      39.652498
# Name: age, dtype: float64

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
import pandas as pd

married_status = ['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse']
non_married_status = ['Divorced', 'Never-married', 'Separated', 'Widowed']

data = pd.read_csv("./data/adult.data.csv")
married = data[data['marital-status'].isin(married_status)]
non_married = data[data['marital-status'].isin(non_married_status)]
man_married = married[married['sex'] == 'Male']
man_non_married = non_married[non_married['sex'] == 'Male']
percent_more_salary_married = len(man_married[man_married['salary'] == '>50K']) / len(man_married) * 100
percent_more_salary_non_married = len(man_non_married[man_non_married['salary'] == '>50K']) / len(man_non_married) * 100

print(percent_more_salary_married, percent_more_salary_non_married)
# Out:
# 44.05139945351156 8.449509031397746

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
max_hours = data['hours-per-week'].max()
max_workers = data[data['hours-per-week'] == max_hours]
max_workers_more_salary = max_workers[max_workers['salary'] == '>50K']
max_workers_more_salary_percent = len(max_workers_more_salary) / len(max_workers) * 100

print(max_workers_more_salary_percent)
# Out:
# 29.411764705882355

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
grouped_data = data.groupby(['native-country', 'salary'])
avgAgeGrouped = grouped_data['hours-per-week'].mean()

print(avgAgeGrouped)
# Out:
# native-country  salary
# ?               <=50K     40.164760
#                 >50K      45.547945
# Cambodia        <=50K     41.416667
#                 >50K      40.000000
# Canada          <=50K     37.914634
#                             ...
# United-States   >50K      45.505369
# Vietnam         <=50K     37.193548
#                 >50K      39.200000
# Yugoslavia      <=50K     41.600000
#                 >50K      49.500000
# Name: hours-per-week, Length: 82, dtype: float64

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")

def age_group(age):
    if 16 <= age < 35:
        return 'young'
    elif 35 <= age < 70:
        return 'adult'
    elif 70 <= age <= 100:
        return 'retiree'

data['age-group'] = data['age'].apply(age_group)
grouped_data = data.groupby('age-group')

print(grouped_data.groups)
# Out:
# {'adult': [0, 1, 2, 3, 5, 6, 7, 9, 10, 14, 18, 19, 20, 21, 22, 23, 24, 25, 27, 28, 29, 32, 35, 39, 41, 43, 45, 46, 47, 48, 52, 53, 54, 55, 56, 57, 58, 62, 63, 65, 67, 68, 76, 77, 81, 82, 83, 84, 85, 86, 89, 90, 91, 96, 97, 98, 101, 102, 109, 111, 112, 114, 115, 116, 117, 118, 121, 125, 128, 129, 132, 133, 134, 135, 136, 139, 140, 143, 147, 148, 149, 150, 154, 155, 159, 160, 162, 164, 165, 166, 167, 169, 172, 180, 181, 183, 184, 186, 187, 189, ...], 'retiree': [74, 100, 144, 157, 222, 228, 316, 324, 430, 499, 527, 552, 647, 656, 833, 834, 872, 918, 978, 1034, 1040, 1168, 1229, 1263, 1338, 1458, 1465, 1562, 1579, 1645, 1710, 1768, 1808, 1837, 1935, 1951, 1997, 2003, 2154, 2189, 2303, 2372, 2402, 2483, 2486, 2491, 2511, 2592, 2615, 2665, 2684, 2715, 2754, 2884, 2891, 2906, 2941, 2967, 2999, 3036, 3065, 3082, 3192, 3211, 3213, 3270, 3291, 3297, 3338, 3537, 3588, 3602, 3606, 3624, 3633, 3671, 3689, 3693, 3773, 3777, 3920, 3931, 3963, 3990, 4018, 4070, 4109, 4196, 4236, 4273, 4464, 4613, 4
# ...

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")

def age_group(age):
    if 16 <= age < 35:
        return 'young'
    elif 35 <= age < 70:
        return 'adult'
    elif 70 <= age <= 100:
        return 'retiree'

data['age-group'] = data['age'].apply(age_group)
grouped_data = data.groupby(['age-group', 'salary']).size()
max_more_salary_count = max(grouped_data['adult']['>50K'], grouped_data['retiree']['>50K'], grouped_data['young']['>50K'])
if grouped_data['adult']['>50K'] == max_more_salary_count:
    print('adult', max_more_salary_count)
if grouped_data['retiree']['>50K'] == max_more_salary_count:
    print('retiree', max_more_salary_count)
if grouped_data['young']['>50K'] == max_more_salary_count:
    print('young', max_more_salary_count)
# Out:
# adult 6240

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
import pandas as pd

data = pd.read_csv("./data/adult.data.csv")
grouped_data = data.groupby('occupation')
grouped_data_size = grouped_data.size()
print(grouped_data_size)

def filter_func(grouped_data):
    filtered_groups = []
    for group_name, group_df in grouped_data:
        if group_df['age'].mean() <= 40 and group_df['hours-per-week'].min() > 5:
            filtered_groups.append(group_df)
    filtered_groups = pd.concat(filtered_groups)
    filtered_groups = filtered_groups.groupby('occupation').size()
    return filtered_groups

filtered_grouped_data = filter_func(grouped_data)
print(filtered_grouped_data)
# Out:
# occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
# occupation
# Armed-Forces    9
# dtype: int64
